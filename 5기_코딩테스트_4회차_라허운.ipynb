# %% [markdown]
# ## 1. JadenCase 문자열 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time 

start = time.time()

def solution(s):
    answer =[]
# 답안 작성 부분 ===============
    for i in s.split(" "):
        # print(i)
        answer.append(i.capitalize())
# ==============================
    return answer

print(solution("3people unFollowed me"))
print(solution("for the last week"))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# ['3people', 'Unfollowed', 'Me']
# ['For', 'The', 'Last', 'Week']
# 작동시간: 0.00024 sec

# %% [markdown]
# # 2. 짝지어 제거하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time 

start = time.time()

def solution (s):
# 답안 작성 부분 ===============
    answer =[]

    for i in s:
        if answer and answer[-1]  == i:
            answer.pop()
        else:
            answer.append(i)

    
    return 0 if answer else 1
# ==============================



print(solution("baabaa"))
print(solution("cdcd"))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# 1
# 0
# 작동시간: 0.00040 sec

# %% [markdown]
# # 3. 구명보트

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time 

start = time.time()

def solution(people, limit):
# 답안 작성 부분 ===============
    answer = 0
    people.sort()
    print(people)

    light = 0
    heavi = len(people) - 1
    while light <= heavi:
        if people[light] + people[heavi] <= limit:
            light +=1
            heavi -=1
        else :
            heavi -=1
        answer +=1       


# ==============================
    return answer

print(solution([70, 50, 80, 50],	100))
print(solution([70, 80, 50],	100))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# [50, 50, 70, 80]
# 3
# [50, 70, 80]
# 3
# 작동시간: 0.00046 sec

# %% [markdown]
# # 4.귤 고르기

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time 

start = time.time()

def solution(k, tangerine):
# 답안 작성 부분 ===============
   


# ==============================
    return answer

print(solution(6, [1, 3, 2, 5, 4, 5, 2, 3]))
print(solution(4,	[1, 3, 2, 5, 4, 5, 2, 3]))
print(solution(2,	[1, 1, 1, 1, 2, 2, 2, 3]))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")

# %% [markdown]
# ## 5. 멘토 제안 문제:
#
# ## ※ 인터넷 검색 가능 (코드 공유 완전히 복사 붙여넣기 금지)
#
# ### 1번 문제. 데이콘 주차수요 예측 AI 정형데이터 대회 데이터 핸들링
# ### 1) 진행이유: Final project 대비 대회 규칙 숙지, 정형데이터 핸들링, 머신러닝 복습, 민첩성
#
# ### 2) 대회 링크: https://dacon.io/competitions/official/235745/overview/description
#
# ### 3) 데이터 링크: https://drive.google.com/file/d/1ptr5jO-4PXRSopitAObeU0uoMSu91s9r/view?usp=share_link
#
# ### 4) 개요:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 5) 대회의 규칙을 단답으로 기입하시오

# %%
# 데이터의 종류?:
# - csv 파일 형식으로 되어 있음??
# - train.csv = 학습용 데이터셋
# - test.csv = 테스트 데이터셋
# - age_gender_info.csv = 지역별 임대주택의 나이별, 성별 인구 분포 정보
# - sample_submission.csv = 제출 양식 파일

# 모델 평가 산식이 무엇인가?
# - MAE(Mean Absolute Error)

# Public 평가 데이터는 Test 데이터의 몇 % ?
# - 전체 Test 데이터 중 무작위 33% (50단지)

# Private 평가 데이터는 Test 데이터의 몇 % ?
# - 전체 Test 데이터 중 나머지 67% (100단지)

# 팀 병합 날짜는 언제였는지?
# -  2021.06.10 ~ 2021.07.23

# 코드와 ppt 제출 날짜는 언제였는지?
#- 2021.07.30 ~ 2021.08.05

# %% [markdown]
# ### 6) 모델학습
#
# #### 1. train, valid set 8:2 비율, 훈련과 validation만 진행
#
# #### 2. 훈련 1번만 진행, 퍼포먼스 점수 상관 없음. (머신러닝 앙상블 모델 기준 n_estimator 1, 딥러닝기준 1 epoch) 훈련이 돌아가는것만 확인,
#
# #### 3. validation 코드 필수로 기입

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor


train_data = pd.read_csv('train.csv')

features = ['총세대수', '전용면적', '단지내주차면수']
target = '등록차량수'


x = train_data[features]
y = train_data[target]

X_train, X_valid, y_train, y_valid = train_test_split(x, y, test_size=0.2, random_state=42)



model = RandomForestRegressor(n_estimators=1)

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=1)

# %%
predictions = model.predict(X_valid)

# %%
print(predictions)
# Out:
# [ 246.  505.  572.  606.  498.  416.  417.  322.  313.  870.  562.  700.
#   209.  924.  344.  155. 2315.  507.   96. 1001.  540.  172.   62.  657.
#    96.  902.  129.   65.  172.  831.  451.  365.  179.  579.  375.   93.
#   333. 1350. 1433.  448.   70.  757.  324.  196.  831.  763. 1101.  359.
#   945.  321.  528.  132.  209.  415. 1896.   98.  902.  922. 1159.  359.
#   643.  321.  116.  995. 1145.  763.  613.  540.  700.  840.   96.  982.
#   832. 1044.  129.  364.  359.  396.  922.  780.  120.  780.  881. 1804.
#   196.  979.  481.   98.  396. 1359.  924.  365.  557.  585. 1101.   94.
#   133.  327.  886.  284.  408.  359.  488.  808.   22.   86.  301.  450.
#   129.  793.  127.  362.  321.   98.  328.  349. 1158.  762.  496.  437.
#   793.  129.  430.  129.  347.  552.  638.   90.   62.  349.  770.  267.
#   253.  353.  359.  364.  437.  614. 2315.  124.  359.   98.  793.  782.
#  1284.  873. 1730. 1117. 1145. 1158.  647.  553.  430.  159.  159.  277.
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


y_true = y_valid


mae = mean_absolute_error(y_true, predictions)



print("MAE:", mae)
# Out:
# MAE: 33.49407783417936

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

train_data = pd.read_csv('train.csv')

features = ['총세대수', '전용면적', '단지내주차면수']
target = '등록차량수'


x = train_data[features]
y = train_data[target]

X_train, X_valid, y_train, y_valid = train_test_split(x, y, test_size=0.2, random_state=42)


model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))



model.compile(optimizer='adam', loss='mean_absolute_error')
        
model.fit(X_train, y_train, epochs=10, batch_size=16, verbose=1)
# Out:
# Epoch 1/100
# 148/148 [==============================] - 1s 3ms/step - loss: 188.2679
# Epoch 2/100
# 148/148 [==============================] - 0s 3ms/step - loss: 140.4401
# Epoch 3/100
# 148/148 [==============================] - 1s 4ms/step - loss: 140.2554
# Epoch 4/100
# 148/148 [==============================] - 1s 4ms/step - loss: 136.9294
# Epoch 5/100
# 148/148 [==============================] - 1s 4ms/step - loss: 136.3180
# Epoch 6/100
# 148/148 [==============================] - 1s 3ms/step - loss: 135.6378
# Epoch 7/100
# 148/148 [==============================] - 0s 3ms/step - loss: 133.7522
# Epoch 8/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/lala/Downloads/5기_코딩테스트_4회차_라허운.ipynb Cell 22 in <cell line: 25>()
# ...

# %%
predictions = model.predict(X_valid)
# Out:
# 19/19 [==============================] - 0s 6ms/step

# %%
mae = mean_absolute_error(y_valid, predictions)
print(mae)
# Out:
# 129.94664269494123

# %%
?
