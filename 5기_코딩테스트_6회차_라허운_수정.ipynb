# %% [markdown]
# # 1. [1차] 비밀지도 2018 KAKAO BLIND RECRUITMENT

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# [문제해설](https://tech.kakao.com/2017/09/27/kakao-blind-recruitment-round-1/)

# %%
import time 
import math
start = time.time()
answer=[]
def solution(n, arr1, arr2):
# 답안 작성 부분 ===============
  answer = [ ]
  o = []
  s = []

  for i in range(n):
    o.append(bin(arr1[i])[2:])
    s.append(bin(arr2[i])[2:])
    o[i] = ('0' * (n-len(o[i]))) + o[i]
    s[i] = ('0' * (n-len(s[i]))) + s[i]

    tmp = ''
    for p in range(n):
        if o[i][p] == '1' or s[i][p] == '1':
            tmp += '#'
        elif o[i][p] == '0' and s[i][p] == '0':
            tmp += ' '
    answer.append(tmp)
# ==============================
  return answer

print(solution(5,[9,20,28,18,11], [30,1,21,17,28]))
print(solution(6, [46,33,33,22,31,50],[27,56,19,14,14,10]))
end = time.time()
print("작동시간:", f"{end - start:.5f} sec")
# Out:
# ['#####', '# # #', '### #', '#  ##', '#####']
# ['######', '###  #', '##  ##', ' #### ', ' #####', '### # ']
# 작동시간: 0.00085 sec

# %% [markdown]
# # 2.귤 고르기

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time 
from collections import Counter



start = time.time()

def solution(k, tangerine):
# 답안 작성 부분 ===============
    t = Counter(tangerine)
    answer = 0
    j = 0
    for i in t.most_common() :
        j += i[1]
        answer += 1
        if j >= k :
            break


# ==============================
    return answer

print(solution(6, [1, 3, 2, 5, 4, 5, 2, 3]))
print(solution(4,	[1, 3, 2, 5, 4, 5, 2, 3]))
print(solution(2,	[1, 1, 1, 1, 2, 2, 2, 3]))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# 3
# 2
# 1
# 작동시간: 0.00043 sec

# %% [markdown]
# # 3. [3차] 파일명 정렬 - 2018 KAKAO BLIND RECRUITMENT
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import time 
import re

start = time.time()
def solution(files):

# 답안 작성 부분 ===============
  ing = re.compile('([a-zA-Z- .])+([0-9]+)')
  sorted_files = sorted(files, key=lambda x: (ing.findall(x)[0][0].lower(), int(ing.findall(x)[0][1]), files.index(x)))



# ==============================
  return sorted_files

print(solution(["img12.png", "img10.png", "img02.png", "img1.png", "IMG01.GIF", "img2.JPG"]))
print(solution(["F-5 Freedom Fighter", "B-50 Superfortress", "A-10 Thunderbolt II", "F-14 Tomcat"]))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# ['img1.png', 'IMG01.GIF', 'img02.png', 'img2.JPG', 'img10.png', 'img12.png']
# ['F-5 Freedom Fighter', 'A-10 Thunderbolt II', 'F-14 Tomcat', 'B-50 Superfortress']
# 작동시간: 0.00062 sec

# %% [markdown]
# # 4. 왕실의 나이트 (시간복잡도 제한 : 1초, 그리디 문제)
#
# 행복 왕국의 왕실 정원은 체스판과 같은 8 × 8 좌표 평면이다. 왕실 정원의 특정한 한 칸에 나이트가 서있다.
# 나이트는 매우 충성스러운 신하로서 매일 무술을 연마한다
# 나이트는 말을 타고 있기 때문에 이동을 할 때는 L자 형태로만 이동할 수 있으며 정원 밖으로는 나갈 수 없다
# 나이트는 특정 위치에서 다음과 같은 2가지 경우로 이동할 수 있다
#
# 1. 수평으로 두 칸 이동한 뒤에 수직으로 한 칸 이동하기
# 2. 수직으로 두 칸 이동한 뒤에 수평으로 한 칸 이동하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이처럼 8 × 8 좌표 평면상에서 나이트의 위치가 주어졌을 때 나이트가 이동할 수 있는 경우의 수를 출력하는
# 프로그램을 작성하라. 왕실의 정원에서 행 위치를 표현할 때는 1부터 8로 표현하며, 열 위치를 표현할 때는
# a 부터 h로 표현한다
#
# - c2에 있을 때 이동할 수 있는 경우의 수는 6가지이다
# - a1에 있을 때 이동할 수 있는 경우의 수는 2가지이다
#
# ============================================================================
#
# 입력
#
# 첫째 줄에 8x8 좌표 평면상에서 현재 나이트가 위치한 곳의 좌표를 나타내는 두 문자로 구성된 문자열이 입력된다. 입력 문자는 a1 처럼 열과 행으로 이뤄진다.
#
# 출력
#
# 첫째 줄에 나이트가 이동할 수 있는 경우의 수를 출력하시오.
#
# ============================================================================
#
# 입력 예시
#
# a1
#
# 출력 예시
#
# 2

# %%
import time 

start = time.time()
def solution(s):
# 답안 작성 부분 ===============
  x, y = s[0], int(s[1])
  x_data = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
  answer = 0
  if x_data.index(x) >= x_data.index('c'): # x가 c이상일경우
      answer += 2 if y > 1 else 1
  if x_data.index(x) <= x_data.index('e'): # x가 e이하
      answer += 2 if y > 1 else 1
  if y >= 3:
      if x_data.index(x) >= x_data.index('b') and x_data.index(x) <= x_data.index('g'):
          answer+=2
      else:
          answer+=1
  if y <= 6:
      if x_data.index(x) >= x_data.index('b') and x_data.index(x) <= x_data.index('g'):
          answer+=2
      else:
          answer+=1 


# ==============================
  return answer

print(solution("a1"))

end = time.time()

print("작동시간:", f"{end - start:.5f} sec")
# Out:
# 2
# 작동시간: 0.00147 sec

# %% [markdown]
# # 5. 멘토 제안 AI 문제 (숙제 6월 11일 오후 23:59분까지 멘토에게 DM으로 제출)
#
# ### - 설명: 현재 프로젝트에서 자신이 쓰고 있는 모델 또는 방법론이나 관심있는 분야의 1개 논문을 읽고, 서론, Data, Method, 결론, 고찰 등을 작성하여 노션에 정리한 후 노션 링크 공유.
#
# ### - 하는 이유: 논문 ppt 입사면접 대비 훈련
#
# ### - 채점 기준: 제출하기만해도 20점으로 하겠으나, 학습자분들 각자에게 좋은 것이니 열심히 임해주시길 바랍니다.
#
# ### - 학습하고자 하는 포인트: 수단과 방법을 가리지 않고 논문을 해석. 단, copy -100점
